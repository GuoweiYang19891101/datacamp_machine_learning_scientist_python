# %% [markdown]
# ## Introduction to Deep Learning with Keras
#
# **Course Structure:**
# * Chapter 1. Introducing Keras
# * Chapter 2. Going Deeper
# * Chapter 3. Improve Your Model Performance
# * Chapter 4. Advanced Model Architectures
#
# ### CHAPTER 1. Introducing Keras
#
# #### Part 1.1 What is Keras?
#
# **Keras:**
# * Open-source library
# * High-level deep learning framework
# * Takes less code and enables fast experimentation
# * It runs on top of other frameworks (like Tensorflow, Theano, or CNTK)
#
# **Why choose Keras?**
# * Fast industry-ready models
# * Good for both beginners and experts
# * Less code
# * Build any architecture
# * Deploy models in multiple platforms (like Android, iOS, web-apps, etc.)
#
# **Deep Learning advantages:**
# 1. It can do feature engineering by itself, domain experts are not needed
# 2. It works well on unstructured data (like sound, videos, images, etc.)

# %%
# display feature engineering 
from IPython import display

display.Image("Images/16_feature_engineering.PNG")

# %% [markdown]
# #### Part 1.2 Your first neural network
#
# *
